# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidScanu/cas-pratique-reconnaissance-iris/blob/main/reconnaissance_iris_lr_classifier_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://img.freepik.com/free-photo/magnified-single-yellow-fish-eye-with-abstract-pattern-generated-by-ai_188544-9714.jpg"></img>
#
# # Cas Pratique : Reconnaissance d'iris - Partie 1 : Classification oeil gauche ou droit
#
# **David Scanu** - Septembre 2023
#
# ---
#
# Vous êtes un développeur IA, votre entreprise vous a confié la mission de **développer une interface de reconnaissance d’oeil pour une entreprise souhaitant authentifier ses 45 employés** à partir d’un scan de leurs yeux.
#
# ---
#
# ## Partie 1 : Classification oeil gauche ou droit
#
# Développement d'un classificateur qui détecte si l'image est un oeil gauche ou un oeil droit.
#
# ---
#
# ## Sommaire :
#
# - Import des bibliothèques
# - Connection à Google Drive
# - Importation des images depuis Google Drive
# - Construction du jeu de données
# - Encodage des données
# - Split en jeu d'entrainement et jeu de test
# - Prétraitement des images
# - Data Augmentation
# - Callbacks
# - Architècture du modèle
# - Entrainement du modèle
# - Prédictions
# - Affichage des performances
# - Montrer les images mal classées
# - Sauvegarde du modèle
# - Sauvegarde du Label Encoder
# - Sauvegarde des images de test
#
# ---
#
# ## Améliorations possible :
#
# - Ajouter MLFlow
# - Ajouter Tensorboard

# %% [markdown]
# ## Import des bibliothèques

# %%
import os
import random
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras import regularizers
from keras.utils import to_categorical
from tensorflow.keras import layers
from PIL import Image
import cv2
import datetime
import shutil

# %% [markdown]
# ## Connection à Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importation des images depuis Google Drive

# %%
# !unzip "/content/drive/MyDrive/Microsoft IA Simplon ISEN/Passage-titre/Cas pratique 01 - Reconnaissance iris/consignes/MMU-Iris-Database.zip"
# Out:
# Archive:  /content/drive/MyDrive/Microsoft IA Simplon ISEN/Passage-titre/Cas pratique 01 - Reconnaissance iris/consignes/MMU-Iris-Database.zip
#    creating: MMU-Iris-Database/
#    creating: MMU-Iris-Database/1/
#    creating: MMU-Iris-Database/10/
#    creating: MMU-Iris-Database/10/left/
#   inflating: MMU-Iris-Database/10/left/fional1.bmp
#   inflating: MMU-Iris-Database/10/left/fional2.bmp
#   inflating: MMU-Iris-Database/10/left/fional3.bmp
#   inflating: MMU-Iris-Database/10/left/fional4.bmp
#   inflating: MMU-Iris-Database/10/left/fional5.bmp
#   inflating: MMU-Iris-Database/10/left/Thumbs.db
#    creating: MMU-Iris-Database/10/right/
#   inflating: MMU-Iris-Database/10/right/fionar1.bmp
#   inflating: MMU-Iris-Database/10/right/fionar2.bmp
#   inflating: MMU-Iris-Database/10/right/fionar3.bmp
#   inflating: MMU-Iris-Database/10/right/fionar4.bmp
#   inflating: MMU-Iris-Database/10/right/fionar5.bmp
#    creating: MMU-Iris-Database/11/
#    creating: MMU-Iris-Database/11/left/
#   inflating: MMU-Iris-Database/11/left/hockl1.bmp
#   inflating: MMU-Iris-Database/11/left/hockl2.bmp
#   inflating: MMU-Iris-Database/11/left/hockl3.bmp
#   inflating: MMU-Iris-Database/11/left/hockl4.bmp
#   inflating: MMU-Iris-Database/11/left/hockl5.bmp
#    creating: MMU-Iris-Database/11/right/
#   inflating: MMU-Iris-Database/11/right/hockr1.bmp
#   inflating: MMU-Iris-Database/11/right/hockr2.bmp
#   inflating: MMU-Iris-Database/11/right/hockr3.bmp
#   inflating: MMU-Iris-Database/11/right/hockr4.bmp
#   inflating: MMU-Iris-Database/11/right/hockr5.bmp
#    creating: MMU-Iris-Database/12/
#    creating: MMU-Iris-Database/12/left/
#   inflating: MMU-Iris-Database/12/left/kelvinl1.bmp
#   inflating: MMU-Iris-Database/12/left/kelvinl2.bmp
#   inflating: MMU-Iris-Database/12/left/kelvinl3.bmp
#   inflating: MMU-Iris-Database/12/left/kelvinl4.bmp
#   inflating: MMU-Iris-Database/12/left/kelvinl5.bmp
#    creating: MMU-Iris-Database/12/right/
#   inflating: MMU-Iris-Database/12/right/kelvinr1.bmp
#   inflating: MMU-Iris-Database/12/right/kelvinr2.bmp
#   inflating: MMU-Iris-Database/12/right/kelvinr3.bmp
#   inflating: MMU-Iris-Database/12/right/kelvinr4.bmp
#   inflating: MMU-Iris-Database/12/right/kelvinr5.bmp
#    creating: MMU-Iris-Database/13/
#    creating: MMU-Iris-Database/13/left/
#   inflating: MMU-Iris-Database/13/left/lecr1.bmp
#   inflating: MMU-Iris-Database/13/left/lecr2.bmp
#   inflating: MMU-Iris-Database/13/left/lecr3.bmp
#   inflating: MMU-Iris-Database/13/left/lecr4.bmp
#   inflating: MMU-Iris-Database/13/left/lecr5.bmp
#    creating: MMU-Iris-Database/13/right/
#   inflating: MMU-Iris-Database/13/right/lecl2.bmp
#   inflating: MMU-Iris-Database/13/right/lecl3.bmp
#   inflating: MMU-Iris-Database/13/right/lecl4.bmp
#   inflating: MMU-Iris-Database/13/right/lecl5.bmp
#   inflating: MMU-Iris-Database/13/right/lec_1.bmp
#    creating: MMU-Iris-Database/14/
#    creating: MMU-Iris-Database/14/left/
#   inflating: MMU-Iris-Database/14/left/liujwl1.bmp
#   inflating: MMU-Iris-Database/14/left/liujwl2.bmp
#   inflating: MMU-Iris-Database/14/left/liujwl3.bmp
#   inflating: MMU-Iris-Database/14/left/liujwl4.bmp
#   inflating: MMU-Iris-Database/14/left/liujwl5.bmp
#    creating: MMU-Iris-Database/14/right/
#   inflating: MMU-Iris-Database/14/right/liujwr1.bmp
#   inflating: MMU-Iris-Database/14/right/liujwr2.bmp
#   inflating: MMU-Iris-Database/14/right/liujwr3.bmp
#   inflating: MMU-Iris-Database/14/right/liujwr4.bmp
#   inflating: MMU-Iris-Database/14/right/liujwr5.bmp
#    creating: MMU-Iris-Database/15/
#    creating: MMU-Iris-Database/15/left/
#   inflating: MMU-Iris-Database/15/left/lokel1.bmp
#   inflating: MMU-Iris-Database/15/left/lokel2.bmp
#   inflating: MMU-Iris-Database/15/left/lokel3.bmp
#   inflating: MMU-Iris-Database/15/left/lokel4.bmp
#   inflating: MMU-Iris-Database/15/left/lokel5.bmp
#    creating: MMU-Iris-Database/15/right/
#   inflating: MMU-Iris-Database/15/right/loker1.bmp
#   inflating: MMU-Iris-Database/15/right/loker2.bmp
#   inflating: MMU-Iris-Database/15/right/loker3.bmp
#   inflating: MMU-Iris-Database/15/right/loker4.bmp
#   inflating: MMU-Iris-Database/15/right/loker5.bmp
#    creating: MMU-Iris-Database/16/
#    creating: MMU-Iris-Database/16/left/
#   inflating: MMU-Iris-Database/16/left/lowyfl1.bmp
#   inflating: MMU-Iris-Database/16/left/lowyfl2.bmp
#   inflating: MMU-Iris-Database/16/left/lowyfl3.bmp
#   inflating: MMU-Iris-Database/16/left/lowyfl4.bmp
#   inflating: MMU-Iris-Database/16/left/lowyfl5.bmp
#    creating: MMU-Iris-Database/16/right/
#   inflating: MMU-Iris-Database/16/right/lowyfr1.bmp
#   inflating: MMU-Iris-Database/16/right/lowyfr2.bmp
#   inflating: MMU-Iris-Database/16/right/lowyfr3.bmp
#   inflating: MMU-Iris-Database/16/right/lowyfr4.bmp
#   inflating: MMU-Iris-Database/16/right/lowyfr5.bmp
#    creating: MMU-Iris-Database/17/
#    creating: MMU-Iris-Database/17/left/
#   inflating: MMU-Iris-Database/17/left/lpjl1.bmp
#   inflating: MMU-Iris-Database/17/left/lpjl2.bmp
#   inflating: MMU-Iris-Database/17/left/lpjl3.bmp
#   inflating: MMU-Iris-Database/17/left/lpjl4.bmp
#   inflating: MMU-Iris-Database/17/left/lpjl5.bmp
#    creating: MMU-Iris-Database/17/right/
#   inflating: MMU-Iris-Database/17/right/lpjr1.bmp
#   inflating: MMU-Iris-Database/17/right/lpjr2.bmp
#   inflating: MMU-Iris-Database/17/right/lpjr3.bmp
#   inflating: MMU-Iris-Database/17/right/lpjr4.bmp
#   inflating: MMU-Iris-Database/17/right/lpjr5.bmp
#    creating: MMU-Iris-Database/18/
#    creating: MMU-Iris-Database/18/left/
#   inflating: MMU-Iris-Database/18/left/mahskl1.bmp
#   inflating: MMU-Iris-Database/18/left/mahskl2.bmp
#   inflating: MMU-Iris-Database/18/left/mahskl3.bmp
#   inflating: MMU-Iris-Database/18/left/mahskl4.bmp
#   inflating: MMU-Iris-Database/18/left/mahskl5.bmp
#    creating: MMU-Iris-Database/18/right/
#   inflating: MMU-Iris-Database/18/right/mahskr1.bmp
#   inflating: MMU-Iris-Database/18/right/mahskr2.bmp
#   inflating: MMU-Iris-Database/18/right/mahskr3.bmp
#   inflating: MMU-Iris-Database/18/right/mahskr4.bmp
#   inflating: MMU-Iris-Database/18/right/mahskr5.bmp
#    creating: MMU-Iris-Database/19/
#    creating: MMU-Iris-Database/19/left/
#   inflating: MMU-Iris-Database/19/left/maranl1.bmp
#   inflating: MMU-Iris-Database/19/left/maranl2.bmp
#   inflating: MMU-Iris-Database/19/left/maranl3.bmp
#   inflating: MMU-Iris-Database/19/left/maranl4.bmp
#   inflating: MMU-Iris-Database/19/left/maranl5.bmp
#    creating: MMU-Iris-Database/19/right/
#   inflating: MMU-Iris-Database/19/right/maranr1.bmp
#   inflating: MMU-Iris-Database/19/right/maranr2.bmp
#   inflating: MMU-Iris-Database/19/right/maranr3.bmp
#   inflating: MMU-Iris-Database/19/right/maranr4.bmp
#   inflating: MMU-Iris-Database/19/right/maranr5.bmp
#    creating: MMU-Iris-Database/1/left/
#   inflating: MMU-Iris-Database/1/left/aeval1.bmp
#   inflating: MMU-Iris-Database/1/left/aeval2.bmp
#   inflating: MMU-Iris-Database/1/left/aeval3.bmp
#   inflating: MMU-Iris-Database/1/left/aeval4.bmp
#   inflating: MMU-Iris-Database/1/left/aeval5.bmp
#   inflating: MMU-Iris-Database/1/left/Thumbs.db
#    creating: MMU-Iris-Database/1/right/
#   inflating: MMU-Iris-Database/1/right/aevar1.bmp
#   inflating: MMU-Iris-Database/1/right/aevar2.bmp
#   inflating: MMU-Iris-Database/1/right/aevar3.bmp
#   inflating: MMU-Iris-Database/1/right/aevar4.bmp
#   inflating: MMU-Iris-Database/1/right/aevar5.bmp
#   inflating: MMU-Iris-Database/1/right/Thumbs.db
#    creating: MMU-Iris-Database/2/
#    creating: MMU-Iris-Database/20/
#    creating: MMU-Iris-Database/20/left/
#   inflating: MMU-Iris-Database/20/left/masl1.bmp
#   inflating: MMU-Iris-Database/20/left/masl2.bmp
#   inflating: MMU-Iris-Database/20/left/masl3.bmp
#   inflating: MMU-Iris-Database/20/left/masl4.bmp
#   inflating: MMU-Iris-Database/20/left/masl5.bmp
#    creating: MMU-Iris-Database/20/right/
#   inflating: MMU-Iris-Database/20/right/masr1.bmp
#   inflating: MMU-Iris-Database/20/right/masr2.bmp
#   inflating: MMU-Iris-Database/20/right/masr3.bmp
#   inflating: MMU-Iris-Database/20/right/masr4.bmp
#   inflating: MMU-Iris-Database/20/right/masr5.bmp
#    creating: MMU-Iris-Database/21/
#    creating: MMU-Iris-Database/21/left/
#   inflating: MMU-Iris-Database/21/left/mazwanl1.bmp
#   inflating: MMU-Iris-Database/21/left/mazwanl2.bmp
#   inflating: MMU-Iris-Database/21/left/mazwanl3.bmp
#   inflating: MMU-Iris-Database/21/left/mazwanl4.bmp
#   inflating: MMU-Iris-Database/21/left/mazwanl5.bmp
#    creating: MMU-Iris-Database/21/right/
#   inflating: MMU-Iris-Database/21/right/mazwanr1.bmp
#   inflating: MMU-Iris-Database/21/right/mazwanr2.bmp
#   inflating: MMU-Iris-Database/21/right/mazwanr3.bmp
#   inflating: MMU-Iris-Database/21/right/mazwanr4.bmp
#   inflating: MMU-Iris-Database/21/right/mazwanr5.bmp
#    creating: MMU-Iris-Database/22/
#    creating: MMU-Iris-Database/22/left/
#   inflating: MMU-Iris-Database/22/left/mimil1.bmp
#   inflating: MMU-Iris-Database/22/left/mimil2.bmp
#   inflating: MMU-Iris-Database/22/left/mimil3.bmp
#   inflating: MMU-Iris-Database/22/left/mimil4.bmp
#   inflating: MMU-Iris-Database/22/left/mimil5.bmp
#    creating: MMU-Iris-Database/22/right/
#   inflating: MMU-Iris-Database/22/right/mimir1.bmp
#   inflating: MMU-Iris-Database/22/right/mimir2.bmp
#   inflating: MMU-Iris-Database/22/right/mimir3.bmp
#   inflating: MMU-Iris-Database/22/right/mimir4.bmp
#   inflating: MMU-Iris-Database/22/right/mimir5.bmp
#    creating: MMU-Iris-Database/23/
#    creating: MMU-Iris-Database/23/left/
#   inflating: MMU-Iris-Database/23/left/minglil1.bmp
#   inflating: MMU-Iris-Database/23/left/minglil2.bmp
#   inflating: MMU-Iris-Database/23/left/minglil3.bmp
#   inflating: MMU-Iris-Database/23/left/minglil4.bmp
#   inflating: MMU-Iris-Database/23/left/minglil5.bmp
#    creating: MMU-Iris-Database/23/right/
#   inflating: MMU-Iris-Database/23/right/minglir1.bmp
#   inflating: MMU-Iris-Database/23/right/minglir2.bmp
#   inflating: MMU-Iris-Database/23/right/minglir3.bmp
#   inflating: MMU-Iris-Database/23/right/minglir4.bmp
#   inflating: MMU-Iris-Database/23/right/minglir5.bmp
#    creating: MMU-Iris-Database/24/
#    creating: MMU-Iris-Database/24/left/
#   inflating: MMU-Iris-Database/24/left/ngkokwhyl1.bmp
#   inflating: MMU-Iris-Database/24/left/ngkokwhyl2.bmp
#   inflating: MMU-Iris-Database/24/left/ngkokwhyl3.bmp
#   inflating: MMU-Iris-Database/24/left/ngkokwhyl4.bmp
#   inflating: MMU-Iris-Database/24/left/ngkokwhyl5.bmp
#    creating: MMU-Iris-Database/24/right/
#   inflating: MMU-Iris-Database/24/right/ngkokwhyr1.bmp
#   inflating: MMU-Iris-Database/24/right/ngkokwhyr2.bmp
#   inflating: MMU-Iris-Database/24/right/ngkokwhyr3.bmp
#   inflating: MMU-Iris-Database/24/right/ngkokwhyr4.bmp
#   inflating: MMU-Iris-Database/24/right/ngkokwhyr5.bmp
#    creating: MMU-Iris-Database/25/
#    creating: MMU-Iris-Database/25/left/
#   inflating: MMU-Iris-Database/25/left/nkll1.bmp
#   inflating: MMU-Iris-Database/25/left/nkll2.bmp
#   inflating: MMU-Iris-Database/25/left/nkll3.bmp
#   inflating: MMU-Iris-Database/25/left/nkll4.bmp
#   inflating: MMU-Iris-Database/25/left/nkll5.bmp
#    creating: MMU-Iris-Database/25/right/
#   inflating: MMU-Iris-Database/25/right/nklr1.bmp
#   inflating: MMU-Iris-Database/25/right/nklr2.bmp
#   inflating: MMU-Iris-Database/25/right/nklr3.bmp
#   inflating: MMU-Iris-Database/25/right/nklr4.bmp
#   inflating: MMU-Iris-Database/25/right/nklr5.bmp
#    creating: MMU-Iris-Database/26/
#    creating: MMU-Iris-Database/26/left/
#   inflating: MMU-Iris-Database/26/left/norazal1.bmp
#   inflating: MMU-Iris-Database/26/left/norazal2.bmp
#   inflating: MMU-Iris-Database/26/left/norazal3.bmp
#   inflating: MMU-Iris-Database/26/left/norazal4.bmp
#   inflating: MMU-Iris-Database/26/left/norazal5.bmp
#    creating: MMU-Iris-Database/26/right/
#   inflating: MMU-Iris-Database/26/right/norazar1.bmp
#   inflating: MMU-Iris-Database/26/right/norazar2.bmp
#   inflating: MMU-Iris-Database/26/right/norazar3.bmp
#   inflating: MMU-Iris-Database/26/right/norazar4.bmp
#   inflating: MMU-Iris-Database/26/right/norazar5.bmp
#    creating: MMU-Iris-Database/27/
#    creating: MMU-Iris-Database/27/left/
#   inflating: MMU-Iris-Database/27/left/norsuhaidahl1.bmp
#   inflating: MMU-Iris-Database/27/left/norsuhaidahl2.bmp
#   inflating: MMU-Iris-Database/27/left/norsuhaidahl3.bmp
#   inflating: MMU-Iris-Database/27/left/norsuhaidahl4.bmp
#   inflating: MMU-Iris-Database/27/left/norsuhaidahl5.bmp
#    creating: MMU-Iris-Database/27/right/
#   inflating: MMU-Iris-Database/27/right/norsuhaidahr1.bmp
#   inflating: MMU-Iris-Database/27/right/norsuhaidahr2.bmp
#   inflating: MMU-Iris-Database/27/right/norsuhaidahr3.bmp
#   inflating: MMU-Iris-Database/27/right/norsuhaidahr4.bmp
#   inflating: MMU-Iris-Database/27/right/norsuhaidahr5.bmp
#    creating: MMU-Iris-Database/28/
#    creating: MMU-Iris-Database/28/left/
#   inflating: MMU-Iris-Database/28/left/ongbll1.bmp
#   inflating: MMU-Iris-Database/28/left/ongbll2.bmp
#   inflating: MMU-Iris-Database/28/left/ongbll3.bmp
#   inflating: MMU-Iris-Database/28/left/ongbll4.bmp
#   inflating: MMU-Iris-Database/28/left/ongbll5.bmp
#    creating: MMU-Iris-Database/28/right/
#   inflating: MMU-Iris-Database/28/right/ongblr1.bmp
#   inflating: MMU-Iris-Database/28/right/ongblr2.bmp
#   inflating: MMU-Iris-Database/28/right/ongblr3.bmp
#   inflating: MMU-Iris-Database/28/right/ongblr4.bmp
#   inflating: MMU-Iris-Database/28/right/ongblr5.bmp
#    creating: MMU-Iris-Database/29/
#    creating: MMU-Iris-Database/29/left/
#   inflating: MMU-Iris-Database/29/left/pcll1.bmp
#   inflating: MMU-Iris-Database/29/left/pcll2.bmp
#   inflating: MMU-Iris-Database/29/left/pcll3.bmp
#   inflating: MMU-Iris-Database/29/left/pcll4.bmp
#   inflating: MMU-Iris-Database/29/left/pcll5.bmp
#    creating: MMU-Iris-Database/29/right/
#   inflating: MMU-Iris-Database/29/right/pclr1.bmp
#   inflating: MMU-Iris-Database/29/right/pclr2.bmp
#   inflating: MMU-Iris-Database/29/right/pclr3.bmp
#   inflating: MMU-Iris-Database/29/right/pclr4.bmp
#   inflating: MMU-Iris-Database/29/right/pclr5.bmp
#    creating: MMU-Iris-Database/2/left/
#   inflating: MMU-Iris-Database/2/left/bryanl1.bmp
#   inflating: MMU-Iris-Database/2/left/bryanl2.bmp
#   inflating: MMU-Iris-Database/2/left/bryanl3.bmp
#   inflating: MMU-Iris-Database/2/left/bryanl4.bmp
#   inflating: MMU-Iris-Database/2/left/bryanl5.bmp
#    creating: MMU-Iris-Database/2/right/
#   inflating: MMU-Iris-Database/2/right/bryanr1.bmp
#   inflating: MMU-Iris-Database/2/right/bryanr2.bmp
#   inflating: MMU-Iris-Database/2/right/bryanr3.bmp
#   inflating: MMU-Iris-Database/2/right/bryanr4.bmp
#   inflating: MMU-Iris-Database/2/right/bryanr5.bmp
#    creating: MMU-Iris-Database/3/
#    creating: MMU-Iris-Database/30/
#    creating: MMU-Iris-Database/30/left/
#   inflating: MMU-Iris-Database/30/left/philipl1.bmp
#   inflating: MMU-Iris-Database/30/left/philipl2.bmp
#   inflating: MMU-Iris-Database/30/left/philipl3.bmp
#   inflating: MMU-Iris-Database/30/left/philipl4.bmp
#   inflating: MMU-Iris-Database/30/left/philipl5.bmp
#    creating: MMU-Iris-Database/30/right/
#   inflating: MMU-Iris-Database/30/right/philipr1.bmp
#   inflating: MMU-Iris-Database/30/right/philipr2.bmp
#   inflating: MMU-Iris-Database/30/right/philipr3.bmp
#   inflating: MMU-Iris-Database/30/right/philipr4.bmp
#   inflating: MMU-Iris-Database/30/right/philipr5.bmp
#    creating: MMU-Iris-Database/31/
#    creating: MMU-Iris-Database/31/left/
#   inflating: MMU-Iris-Database/31/left/roslil1.bmp
#   inflating: MMU-Iris-Database/31/left/roslil2.bmp
#   inflating: MMU-Iris-Database/31/left/roslil3.bmp
#   inflating: MMU-Iris-Database/31/left/roslil4.bmp
#   inflating: MMU-Iris-Database/31/left/roslil5.bmp
#    creating: MMU-Iris-Database/31/right/
#   inflating: MMU-Iris-Database/31/right/roslir1.bmp
#   inflating: MMU-Iris-Database/31/right/roslir2.bmp
#   inflating: MMU-Iris-Database/31/right/roslir3.bmp
#   inflating: MMU-Iris-Database/31/right/roslir4.bmp
#   inflating: MMU-Iris-Database/31/right/roslir5.bmp
#    creating: MMU-Iris-Database/32/
#    creating: MMU-Iris-Database/32/left/
#   inflating: MMU-Iris-Database/32/left/salal1.bmp
#   inflating: MMU-Iris-Database/32/left/salal2.bmp
#   inflating: MMU-Iris-Database/32/left/salal3.bmp
#   inflating: MMU-Iris-Database/32/left/salal4.bmp
#   inflating: MMU-Iris-Database/32/left/salal5.bmp
#    creating: MMU-Iris-Database/32/right/
#   inflating: MMU-Iris-Database/32/right/salar1.bmp
#   inflating: MMU-Iris-Database/32/right/salar2.bmp
#   inflating: MMU-Iris-Database/32/right/salar3.bmp
#   inflating: MMU-Iris-Database/32/right/salar4.bmp
#   inflating: MMU-Iris-Database/32/right/salar5.bmp
#    creating: MMU-Iris-Database/33/
#    creating: MMU-Iris-Database/33/left/
#   inflating: MMU-Iris-Database/33/left/sarinal1.bmp
#   inflating: MMU-Iris-Database/33/left/sarinal2.bmp
#   inflating: MMU-Iris-Database/33/left/sarinal3.bmp
#   inflating: MMU-Iris-Database/33/left/sarinal4.bmp
#   inflating: MMU-Iris-Database/33/left/sarinal5.bmp
#    creating: MMU-Iris-Database/33/right/
#   inflating: MMU-Iris-Database/33/right/sarinar1.bmp
#   inflating: MMU-Iris-Database/33/right/sarinar2.bmp
#   inflating: MMU-Iris-Database/33/right/sarinar3.bmp
#   inflating: MMU-Iris-Database/33/right/sarinar4.bmp
#   inflating: MMU-Iris-Database/33/right/sarinar5.bmp
#    creating: MMU-Iris-Database/34/
#    creating: MMU-Iris-Database/34/left/
#   inflating: MMU-Iris-Database/34/left/sitil1.bmp
#   inflating: MMU-Iris-Database/34/left/sitil2.bmp
#   inflating: MMU-Iris-Database/34/left/sitil3.bmp
#   inflating: MMU-Iris-Database/34/left/sitil4.bmp
#   inflating: MMU-Iris-Database/34/left/sitil5.bmp
#    creating: MMU-Iris-Database/34/right/
#   inflating: MMU-Iris-Database/34/right/sitir1.bmp
#   inflating: MMU-Iris-Database/34/right/sitir2.bmp
#   inflating: MMU-Iris-Database/34/right/sitir3.bmp
#   inflating: MMU-Iris-Database/34/right/sitir4.bmp
#   inflating: MMU-Iris-Database/34/right/sitir5.bmp
#    creating: MMU-Iris-Database/35/
#    creating: MMU-Iris-Database/35/left/
#   inflating: MMU-Iris-Database/35/left/suzailil1.bmp
#   inflating: MMU-Iris-Database/35/left/suzailil2.bmp
#   inflating: MMU-Iris-Database/35/left/suzailil3.bmp
#   inflating: MMU-Iris-Database/35/left/suzailil4.bmp
#   inflating: MMU-Iris-Database/35/left/suzailil5.bmp
#    creating: MMU-Iris-Database/35/right/
#   inflating: MMU-Iris-Database/35/right/suzailir1.bmp
#   inflating: MMU-Iris-Database/35/right/suzailir2.bmp
#   inflating: MMU-Iris-Database/35/right/suzailir3.bmp
#   inflating: MMU-Iris-Database/35/right/suzailir4.bmp
#   inflating: MMU-Iris-Database/35/right/suzailir5.bmp
#    creating: MMU-Iris-Database/36/
#    creating: MMU-Iris-Database/36/left/
#   inflating: MMU-Iris-Database/36/left/tanwnl1.bmp
#   inflating: MMU-Iris-Database/36/left/tanwnl2.bmp
#   inflating: MMU-Iris-Database/36/left/tanwnl3.bmp
#   inflating: MMU-Iris-Database/36/left/tanwnl4.bmp
#   inflating: MMU-Iris-Database/36/left/tanwnl5.bmp
#    creating: MMU-Iris-Database/36/right/
#   inflating: MMU-Iris-Database/36/right/tanwnr1.bmp
#   inflating: MMU-Iris-Database/36/right/tanwnr2.bmp
#   inflating: MMU-Iris-Database/36/right/tanwnr3.bmp
#   inflating: MMU-Iris-Database/36/right/tanwnr4.bmp
#   inflating: MMU-Iris-Database/36/right/tanwnr5.bmp
#    creating: MMU-Iris-Database/37/
#    creating: MMU-Iris-Database/37/left/
#   inflating: MMU-Iris-Database/37/left/thomasl1.bmp
#   inflating: MMU-Iris-Database/37/left/thomasl2.bmp
#   inflating: MMU-Iris-Database/37/left/thomasl3.bmp
#   inflating: MMU-Iris-Database/37/left/thomasl4.bmp
#   inflating: MMU-Iris-Database/37/left/thomasl5.bmp
#   inflating: MMU-Iris-Database/37/left/Thumbs.db
#    creating: MMU-Iris-Database/37/right/
#   inflating: MMU-Iris-Database/37/right/thomasr1.bmp
#   inflating: MMU-Iris-Database/37/right/thomasr2.bmp
#   inflating: MMU-Iris-Database/37/right/thomasr3.bmp
#   inflating: MMU-Iris-Database/37/right/thomasr4.bmp
#   inflating: MMU-Iris-Database/37/right/thomasr5.bmp
#    creating: MMU-Iris-Database/38/
#    creating: MMU-Iris-Database/38/left/
#   inflating: MMU-Iris-Database/38/left/tickl1.bmp
#   inflating: MMU-Iris-Database/38/left/tickl2.bmp
#   inflating: MMU-Iris-Database/38/left/tickl3.bmp
#   inflating: MMU-Iris-Database/38/left/tickl4.bmp
#   inflating: MMU-Iris-Database/38/left/tickl5.bmp
#    creating: MMU-Iris-Database/38/right/
#   inflating: MMU-Iris-Database/38/right/tickr1.bmp
#   inflating: MMU-Iris-Database/38/right/tickr2.bmp
#   inflating: MMU-Iris-Database/38/right/tickr3.bmp
#   inflating: MMU-Iris-Database/38/right/tickr4.bmp
#   inflating: MMU-Iris-Database/38/right/tickr5.bmp
#    creating: MMU-Iris-Database/39/
#    creating: MMU-Iris-Database/39/left/
#   inflating: MMU-Iris-Database/39/left/tingcyl1.bmp
#   inflating: MMU-Iris-Database/39/left/tingcyl2.bmp
#   inflating: MMU-Iris-Database/39/left/tingcyl3.bmp
#   inflating: MMU-Iris-Database/39/left/tingcyl4.bmp
#   inflating: MMU-Iris-Database/39/left/tingcyl5.bmp
#    creating: MMU-Iris-Database/39/right/
#   inflating: MMU-Iris-Database/39/right/tingcyr1.bmp
#   inflating: MMU-Iris-Database/39/right/tingcyr2.bmp
#   inflating: MMU-Iris-Database/39/right/tingcyr3.bmp
#   inflating: MMU-Iris-Database/39/right/tingcyr4.bmp
#   inflating: MMU-Iris-Database/39/right/tingcyr5.bmp
#    creating: MMU-Iris-Database/3/left/
#   inflating: MMU-Iris-Database/3/left/chingycl1.bmp
#   inflating: MMU-Iris-Database/3/left/chingycl2.bmp
#   inflating: MMU-Iris-Database/3/left/chingycl3.bmp
#   inflating: MMU-Iris-Database/3/left/chingycl4.bmp
#   inflating: MMU-Iris-Database/3/left/chingycl5.bmp
#    creating: MMU-Iris-Database/3/right/
#   inflating: MMU-Iris-Database/3/right/chingycr1.bmp
#   inflating: MMU-Iris-Database/3/right/chingycr2.bmp
#   inflating: MMU-Iris-Database/3/right/chingycr3.bmp
#   inflating: MMU-Iris-Database/3/right/chingycr4.bmp
#   inflating: MMU-Iris-Database/3/right/chingycr5.bmp
#    creating: MMU-Iris-Database/40/
#    creating: MMU-Iris-Database/40/left/
#   inflating: MMU-Iris-Database/40/left/tonghll1.bmp
#   inflating: MMU-Iris-Database/40/left/tonghll2.bmp
#   inflating: MMU-Iris-Database/40/left/tonghll3.bmp
#   inflating: MMU-Iris-Database/40/left/tonghll4.bmp
#   inflating: MMU-Iris-Database/40/left/tonghll5.bmp
#    creating: MMU-Iris-Database/40/right/
#   inflating: MMU-Iris-Database/40/right/tonghlr1.bmp
#   inflating: MMU-Iris-Database/40/right/tonghlr2.bmp
#   inflating: MMU-Iris-Database/40/right/tonghlr3.bmp
#   inflating: MMU-Iris-Database/40/right/tonghlr4.bmp
#   inflating: MMU-Iris-Database/40/right/tonghlr5.bmp
#    creating: MMU-Iris-Database/41/
#    creating: MMU-Iris-Database/41/left/
#   inflating: MMU-Iris-Database/41/left/vimalal1.bmp
#   inflating: MMU-Iris-Database/41/left/vimalal2.bmp
#   inflating: MMU-Iris-Database/41/left/vimalal3.bmp
#   inflating: MMU-Iris-Database/41/left/vimalal4.bmp
#   inflating: MMU-Iris-Database/41/left/vimalal5.bmp
#    creating: MMU-Iris-Database/41/right/
#   inflating: MMU-Iris-Database/41/right/vimalar1.bmp
#   inflating: MMU-Iris-Database/41/right/vimalar2.bmp
#   inflating: MMU-Iris-Database/41/right/vimalar3.bmp
#   inflating: MMU-Iris-Database/41/right/vimalar4.bmp
#   inflating: MMU-Iris-Database/41/right/vimalar5.bmp
#    creating: MMU-Iris-Database/42/
#    creating: MMU-Iris-Database/42/left/
#   inflating: MMU-Iris-Database/42/left/Thumbs.db
#   inflating: MMU-Iris-Database/42/left/weecml1.bmp
#   inflating: MMU-Iris-Database/42/left/weecml2.bmp
#   inflating: MMU-Iris-Database/42/left/weecml3.bmp
#   inflating: MMU-Iris-Database/42/left/weecml4.bmp
#   inflating: MMU-Iris-Database/42/left/weecml5.bmp
#    creating: MMU-Iris-Database/42/right/
#   inflating: MMU-Iris-Database/42/right/weecmr1.bmp
#   inflating: MMU-Iris-Database/42/right/weecmr2.bmp
#   inflating: MMU-Iris-Database/42/right/weecmr3.bmp
#   inflating: MMU-Iris-Database/42/right/weecmr4.bmp
#   inflating: MMU-Iris-Database/42/right/weecmr5.bmp
#    creating: MMU-Iris-Database/43/
#    creating: MMU-Iris-Database/43/left/
#   inflating: MMU-Iris-Database/43/left/winr1.bmp
#   inflating: MMU-Iris-Database/43/left/winr2.bmp
#   inflating: MMU-Iris-Database/43/left/winr3.bmp
#   inflating: MMU-Iris-Database/43/left/winr4.bmp
#   inflating: MMU-Iris-Database/43/left/winr5.bmp
#    creating: MMU-Iris-Database/43/right/
#   inflating: MMU-Iris-Database/43/right/winl1.bmp
#   inflating: MMU-Iris-Database/43/right/winl2.bmp
#   inflating: MMU-Iris-Database/43/right/winl3.bmp
#   inflating: MMU-Iris-Database/43/right/winl4.bmp
#   inflating: MMU-Iris-Database/43/right/winl5.bmp
#    creating: MMU-Iris-Database/44/
#    creating: MMU-Iris-Database/44/left/
#   inflating: MMU-Iris-Database/44/left/yannl1.bmp
#   inflating: MMU-Iris-Database/44/left/yannl2.bmp
#   inflating: MMU-Iris-Database/44/left/yannl3.bmp
#   inflating: MMU-Iris-Database/44/left/yannl4.bmp
#   inflating: MMU-Iris-Database/44/left/yannl5.bmp
#    creating: MMU-Iris-Database/44/right/
#   inflating: MMU-Iris-Database/44/right/yannr1.bmp
#   inflating: MMU-Iris-Database/44/right/yannr2.bmp
#   inflating: MMU-Iris-Database/44/right/yannr3.bmp
#   inflating: MMU-Iris-Database/44/right/yannr4.bmp
#   inflating: MMU-Iris-Database/44/right/yannr5.bmp
#    creating: MMU-Iris-Database/45/
#    creating: MMU-Iris-Database/45/left/
#   inflating: MMU-Iris-Database/45/left/zaridahl1.bmp
#   inflating: MMU-Iris-Database/45/left/zaridahl2.bmp
#   inflating: MMU-Iris-Database/45/left/zaridahl3.bmp
#   inflating: MMU-Iris-Database/45/left/zaridahl4.bmp
#   inflating: MMU-Iris-Database/45/left/zaridahl5.bmp
#    creating: MMU-Iris-Database/45/right/
#   inflating: MMU-Iris-Database/45/right/zaridahr1.bmp
#   inflating: MMU-Iris-Database/45/right/zaridahr2.bmp
#   inflating: MMU-Iris-Database/45/right/zaridahr3.bmp
#   inflating: MMU-Iris-Database/45/right/zaridahr4.bmp
#   inflating: MMU-Iris-Database/45/right/zaridahr5.bmp
#    creating: MMU-Iris-Database/46/
#    creating: MMU-Iris-Database/46/left/
#   inflating: MMU-Iris-Database/46/left/Thumbs.db
#   inflating: MMU-Iris-Database/46/left/zulaikahl1.bmp
#   inflating: MMU-Iris-Database/46/left/zulaikahl2.bmp
#   inflating: MMU-Iris-Database/46/left/zulaikahl3.bmp
#   inflating: MMU-Iris-Database/46/left/zulaikahl4.bmp
#   inflating: MMU-Iris-Database/46/left/zulaikahl5.bmp
#    creating: MMU-Iris-Database/46/right/
#   inflating: MMU-Iris-Database/46/right/zulaikahr1.bmp
#   inflating: MMU-Iris-Database/46/right/zulaikahr2.bmp
#   inflating: MMU-Iris-Database/46/right/zulaikahr3.bmp
#   inflating: MMU-Iris-Database/46/right/zulaikahr4.bmp
#   inflating: MMU-Iris-Database/46/right/zulaikahr5.bmp
#    creating: MMU-Iris-Database/5/
#    creating: MMU-Iris-Database/5/left/
#   inflating: MMU-Iris-Database/5/left/chongpkl1.bmp
#   inflating: MMU-Iris-Database/5/left/chongpkl2.bmp
#   inflating: MMU-Iris-Database/5/left/chongpkl3.bmp
#   inflating: MMU-Iris-Database/5/left/chongpkl4.bmp
#   inflating: MMU-Iris-Database/5/left/chongpkl5.bmp
#    creating: MMU-Iris-Database/5/right/
#   inflating: MMU-Iris-Database/5/right/chongpkr1.bmp
#   inflating: MMU-Iris-Database/5/right/chongpkr2.bmp
#   inflating: MMU-Iris-Database/5/right/chongpkr3.bmp
#   inflating: MMU-Iris-Database/5/right/chongpkr4.bmp
#   inflating: MMU-Iris-Database/5/right/chongpkr5.bmp
#    creating: MMU-Iris-Database/6/
#    creating: MMU-Iris-Database/6/left/
#   inflating: MMU-Iris-Database/6/left/christinel1.bmp
#   inflating: MMU-Iris-Database/6/left/christinel2.bmp
#   inflating: MMU-Iris-Database/6/left/christinel3.bmp
#   inflating: MMU-Iris-Database/6/left/christinel4.bmp
#   inflating: MMU-Iris-Database/6/left/christinel5.bmp
#    creating: MMU-Iris-Database/6/right/
#   inflating: MMU-Iris-Database/6/right/christiner1.bmp
#   inflating: MMU-Iris-Database/6/right/christiner2.bmp
#   inflating: MMU-Iris-Database/6/right/christiner3.bmp
#   inflating: MMU-Iris-Database/6/right/christiner4.bmp
#   inflating: MMU-Iris-Database/6/right/christiner5.bmp
#    creating: MMU-Iris-Database/7/
#    creating: MMU-Iris-Database/7/left/
#   inflating: MMU-Iris-Database/7/left/chualsl1.bmp
#   inflating: MMU-Iris-Database/7/left/chualsl2.bmp
#   inflating: MMU-Iris-Database/7/left/chualsl3.bmp
#   inflating: MMU-Iris-Database/7/left/chualsl4.bmp
#   inflating: MMU-Iris-Database/7/left/chualsl5.bmp
#   inflating: MMU-Iris-Database/7/left/Thumbs.db
#    creating: MMU-Iris-Database/7/right/
#   inflating: MMU-Iris-Database/7/right/chualsr1.bmp
#   inflating: MMU-Iris-Database/7/right/chualsr2.bmp
#   inflating: MMU-Iris-Database/7/right/chualsr3.bmp
#   inflating: MMU-Iris-Database/7/right/chualsr4.bmp
#   inflating: MMU-Iris-Database/7/right/chualsr5.bmp
#    creating: MMU-Iris-Database/8/
#    creating: MMU-Iris-Database/8/left/
#   inflating: MMU-Iris-Database/8/left/eugenehor1.bmp
#   inflating: MMU-Iris-Database/8/left/eugenehor2.bmp
#   inflating: MMU-Iris-Database/8/left/eugenehor3.bmp
#   inflating: MMU-Iris-Database/8/left/eugenehor4.bmp
#   inflating: MMU-Iris-Database/8/left/eugenehor5.bmp
#    creating: MMU-Iris-Database/8/right/
#   inflating: MMU-Iris-Database/8/right/eugenehol1.bmp
#   inflating: MMU-Iris-Database/8/right/eugenehol2.bmp
#   inflating: MMU-Iris-Database/8/right/eugenehol3.bmp
#   inflating: MMU-Iris-Database/8/right/eugenehol4.bmp
#   inflating: MMU-Iris-Database/8/right/eugenehol5.bmp
#    creating: MMU-Iris-Database/9/
#    creating: MMU-Iris-Database/9/left/
#   inflating: MMU-Iris-Database/9/left/fatmal1.bmp
#   inflating: MMU-Iris-Database/9/left/fatmal2.bmp
#   inflating: MMU-Iris-Database/9/left/fatmal3.bmp
#   inflating: MMU-Iris-Database/9/left/fatmal4.bmp
#   inflating: MMU-Iris-Database/9/left/fatmal5.bmp
#    creating: MMU-Iris-Database/9/right/
#   inflating: MMU-Iris-Database/9/right/fatmar1.bmp
#   inflating: MMU-Iris-Database/9/right/fatmar2.bmp
#   inflating: MMU-Iris-Database/9/right/fatmar3.bmp
#   inflating: MMU-Iris-Database/9/right/fatmar4.bmp
#   inflating: MMU-Iris-Database/9/right/fatmar5.bmp
#   inflating: MMU-Iris-Database/ReadMe.txt

# %% [markdown]
# ## Variables principales

# %%
# Images are 320px width, 240px height and 3 color layers deep (RVB)
img_width = 320
img_height = 240
img_channels = 3
img_dim = (img_height, img_width, img_channels)

TRAIN = False
EPOCHS = 50

backup_folder = '/content/drive/MyDrive/Microsoft IA Simplon ISEN/Passage-titre/Cas pratique 01 - Reconnaissance iris/notebooks/01-left-right-classifier/v2/'

# %% [markdown]
# ## Construction du dataset

# %% [markdown]
# ### Split du dataset dans un nouveau dossier
#
# L'objectif est de construire un nouveau dossier `MMU-Iris-Database-split/` contenant deux sous-dossiers : `train/` et `test/`.
#
# Exemples :
# - `MMU-Iris-Database-split/train/1/left/image01.bmp`
# - `MMU-Iris-Database-split/test/32/right/image03.bmp`

# %%
# Chemin vers le dossier principal contenant les sous-dossiers
og_dataset_folder_path = '/content/MMU-Iris-Database/'
new_dataset_folder_path = '/content/MMU-Iris-Database-split/'

# %%
# @title Fonctions d'aide : création et supression de dossiers

def make_folder(folder_path):
  if not os.path.isdir(folder_path):
    os.mkdir(folder_path)

def make_subfolder(folder_path, subfolder_name):
  subfolder_path = folder_path + subfolder_name  + '/'
  if not os.path.isdir(subfolder_path):
    os.mkdir(subfolder_path)
  return subfolder_path

def delete_folder(folder_path):
  if os.path.isdir(folder_path):
    try:
        shutil.rmtree(folder_path)
        # print('Folder and its content removed')
    except:
        print('Folder not deleted')

# %%
# @title Fonction qui split le dataset en dossier 'train' et dossier 'test'

def make_train_test_folders(og_dataset_folder_path, new_dataset_folder_path, train_size=0.8, random_state=42):
  """
  Fonction qui split le dataset en dossier 'train' et dossier 'test'. Utile pour
  avoir toujours le même split dans les 3 notebooks. De cette manière, nous sommes
  sur qu'une image de test n'est jamais passée dans les données d'entrainement.

  Retourne les chemins vers les dossiers : 'train' et 'test'.
  """
  # Effacer le dossier et tous ses sous-dossiers, s'il existe déjà
  delete_folder(new_dataset_folder_path)
  # Créer le nouveau dossier pour le nouveau dataset, s'il n'existe pas déjà
  make_folder(new_dataset_folder_path)

  # Créer les sous-dossier 'train' et 'test'
  new_train_folder_path = make_subfolder(new_dataset_folder_path, 'train')
  new_test_folder_path = make_subfolder(new_dataset_folder_path, 'test')

  # Parcourir le dossier source
  for id in os.listdir(og_dataset_folder_path):
    og_id_path = os.path.join(og_dataset_folder_path, id)
    if os.path.isdir(og_id_path):
      # Dans le dossier de destination, créer 'train/*id*' et 'train/*id*'
      new_train_id_subfolder = make_subfolder(new_train_folder_path, id)
      new_test_id_subfolder = make_subfolder(new_test_folder_path, id)
      for side in os.listdir(og_id_path):
        og_side_path = os.path.join(og_id_path, side)
        if os.path.isdir(og_side_path):
          # Créer le nouveau dossier 'train/{id}/{side}'
          new_train_id_side_subfolder = make_subfolder(new_train_id_subfolder, side)
          # Créer le nouveau dossier 'test/{id}/{side}'
          new_test_id_side_subfolder= make_subfolder(new_test_id_subfolder, side)
          # Parcourir le dossier original : {id}/{side}/
          # Ajouter à la liste uniquement les fichiers '.bmp', '.jpg', '.png'
          og_images_list = [f for f in os.listdir(og_side_path) if f.lower().endswith(('.bmp', '.jpg', '.png'))]
          # Mélanger la liste d'images
          random.Random(random_state).shuffle(og_images_list)
          # Split les images en train et test
          ratio = train_size
          total_rows = len(og_images_list)
          train_size_rows = int(total_rows * ratio)
          train_imgs = og_images_list[0:train_size_rows]
          test = og_images_list[train_size_rows:]
          # Copier les images dans le nouveau dossier 'train'
          for image_filename in train_imgs:
            og_image_path = os.path.join(og_side_path, image_filename)
            shutil.copy2(og_image_path, new_train_id_side_subfolder)
            # print(f"Old image path : {og_image_path} - TRAIN")
            # print(f"New image path : {new_train_id_side_subfolder}{image_filename}")
          # Copier les images dans le nouveau dossier 'test'
          for image_filename in test:
            og_image_path = os.path.join(og_side_path, image_filename)
            shutil.copy2(og_image_path, new_test_id_side_subfolder)
            # print(f"Old image path : {og_image_path} - TEST")
            # print(f"New image path : {new_test_id_side_subfolder}{image_filename}")

  return new_train_folder_path, new_test_folder_path

# %%
# Création du nouveau dossier contenant les dossiers : 'train' et 'test'
new_train_folder_path, new_test_folder_path = make_train_test_folders(og_dataset_folder_path, new_dataset_folder_path)

# %%
print(new_train_folder_path)
print(new_test_folder_path)
# Out:
# /content/MMU-Iris-Database-split/train/
# /content/MMU-Iris-Database-split/test/

# %%
def make_dataset_side(folder_path):
  """
  Fonction qui retourne les images d'yeux dans la variable X,
  et le coté dans la variable cible y ('left' ou 'right').
  """
  X = []
  y = []

  for id_folder in os.listdir(folder_path):
    id_path = os.path.join(folder_path, id_folder)
    if os.path.isdir(id_path):
      for side in os.listdir(id_path):
        side_path = os.path.join(id_path, side)
        if os.path.isdir(side_path):
          for image_filename in os.listdir(side_path):
            if image_filename.lower().endswith(('.bmp', '.jpg', '.png')):
              image_path = os.path.join(side_path, image_filename)
              image = cv2.imread(image_path) # ndarray
              target = str(side)
              X.append(image)
              y.append(target)
  # Convertit les listes en ndarray
  X = np.array(X)
  y = np.array(y)
  return X, y

# %%
# Création des datasets d'entrainement et de test
X_train, y_train = make_dataset_side(new_train_folder_path)
X_test, y_test = make_dataset_side(new_test_folder_path)

# %%
print(f"Dimensions des images d'entrainement : {X_train.shape}.")
print(f"Dimensions des labels d'entrainement : {y_train.shape}.")
print(f"Dimensions des images de test : {X_test.shape}.")
print(f"Dimensions des labels de test : {y_test.shape}.")
# Out:
# Dimensions des images d'entrainement : (360, 240, 320, 3).
# Dimensions des labels d'entrainement : (360,).
# Dimensions des images de test : (90, 240, 320, 3).
# Dimensions des labels de test : (90,).

# %%
# Exemple d'une image d'entrainement
plt.imshow(X_train[0][:,:,2])

# %% [markdown]
# ## Encodage des labels sous forme d'entiers
#
# Encode les classes cibles sous forme d'entiers avec une valeur comprise entre 0 et n_classes-1.
#
# Ce transformateur doit être utilisé pour coder les valeurs cibles, c'est-à-dire y, et non l'entrée X.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
label_enc_lr = preprocessing.LabelEncoder()

# %%
# Encodage des labels d'entrainement
y_train_enc = label_enc_lr.fit_transform(y_train)
# Encodage des labels de test
y_test_enc = label_enc_lr.fit_transform(y_test)

# %%
# Montre les classes du Label Encoder
label_enc_lr.classes_
# Out:
# array(['left', 'right'], dtype='<U5')

# %% [markdown]
# ## Conversion des index de classes en vecteurs
#
# - https://www.tensorflow.org/api_docs/python/tf/keras/utils/*to_categorical*

# %%
# To categorical
y_train_vect = to_categorical(y_train_enc)
# y_test_vect = to_categorical(y_test_enc) # pas besoin des cibles de test sous forme de vecteurs

# %%
# Un exemple de cible au format vecteur
y_train_vect[0]
# Out:
# array([0., 1.], dtype=float32)

# %%
# Conversion en classes
label_enc_lr.classes_[np.argmax(y_train_vect[0])]
# Out:
# 'right'

# %% [markdown]
# ## Augmentation des données (Data Augmentation)
#
# L'augmentation des données est une technique qui permet de créer artificiellement de nouvelles données à partir d'un ensemble de données existant. Ces nouvelles données sont générées en appliquant des transformations mineures aux données existantes, ou en utilisant d'autres modèles d'apprentissage automatique.
#
# - https://www.tensorflow.org/tutorials/images/data_augmentation?hl=fr
# - https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# %%
# Creation d'une instance de ImageDataGenerator
# On applique les transformations souhaitées sur l'image
datagen = ImageDataGenerator(
  rotation_range=7,
  width_shift_range=0.1,
  height_shift_range=0.1,
  brightness_range=[0.5, 1.2],
  zoom_range=0.1,
  channel_shift_range=0.1,
  fill_mode='wrap' # reflect
)

# %%
def augment_dataset(X_train, y_train, nb_aug_imgs):
  """
  Retourne un ndarray d'images augmentées utilisant 'datagen' (l'instance
  de la classe ImageDataGenerator) et leurs labels associés.
  """
  # Convertit les ndarray en listes
  if isinstance(X_train, np.ndarray):
    X_train = X_train.tolist()
  if isinstance(y_train, np.ndarray):
    y_train = y_train.tolist()

  augmented_images = []
  augmented_labels = []
  for img, label in zip(X_train, y_train) :
    # Ajoute une dimension supplémentaire au Tensor
    img = np.expand_dims(img, axis=0)
    # img = tf.cast(tf.expand_dims(ex_img, 0), tf.float32)
    # Compte le nombre d'itérations de la boucle
    batches = 0
    # Applique le ImageDataGenerator à l'image
    for batch in datagen.flow(img, batch_size=1):
        augmented_images.append(batch[0])
        augmented_labels.append(label)
        batches += 1
        # Generer un nombre d'images puis sortir de la boucle
        if batches >= nb_aug_imgs:
          break
  augmented_images = np.array(augmented_images)
  augmented_labels = np.array(augmented_labels)
  return augmented_images, augmented_labels

# %%
# Visualisation d'un exemple d'image
img = tf.cast(tf.expand_dims(X_train[0], 0), tf.float32)
aug_ex_imgs, aug_ex_labels = augment_dataset(X_train[:1], y_train_vect[:1], 5)

# Display original and augmented images using matplotlib
plt.figure(figsize=(12, 6))

plt.subplot(2, 3, 1)
# plt.imshow(np.array(img[0]))
plt.imshow(img[0].astype(np.uint8)) # Les valeurs des pixels doivent être des entiers et non des nombres décimaux
plt.title('Original Image')

for i, augmented_img in enumerate(aug_ex_imgs):
    plt.subplot(2, 3, i + 2)
    plt.imshow(augmented_img.astype(np.uint8))
    plt.title(f'Augmented Image {i+1}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Augmentation des images d'entrainement
#
# - https://sparkbyexamples.com/numpy/numpy-concatenate-arrays/

# %%
# Géneration des images augmentées
augmented_images, augmented_labels = augment_dataset(X_train, y_train_vect, 5)

# %%
# Ajout des images augmentées aux images d'entrainement
X_train_aug = np.concatenate((X_train, augmented_images))
y_train_vect_aug = np.concatenate((y_train_vect, augmented_labels))

# %%
X_train_aug.shape
# Out:
# (2160, 240, 320, 3)

# %%
y_train_vect_aug.shape
# Out:
# (2160, 2)

# %% [markdown]
# ### Augmentation des images de test

# %%
# Data augmentation des images de test
imgs_test_aug, labels_test_aug = augment_dataset(X_test, y_test_enc, 5)

# Ajout des images augmentées aux images de test
X_test_aug = np.concatenate((X_test, imgs_test_aug))
y_test_enc_aug = np.concatenate((y_test_enc, labels_test_aug))

# %%
X_test_aug.shape
# Out:
# (540, 240, 320, 3)

# %%
y_test_enc_aug.shape
# Out:
# (540,)

# %% [markdown]
# ## Prétraitement de l'image : redimensionnemennt et mise à l'échelle
#
# Les couches de prétraitement des images seront ajoutées aux couches du modèle, juste après la couche Input. Ces couches seront inclues dans le modèle, évitant ainsi de devoir les exporter séparemment.
#
# - https://www.tensorflow.org/tutorials/images/data_augmentation?hl=fr#resizing_and_rescaling
# - https://www.tensorflow.org/guide/keras/preprocessing_layers
# - https://www.tensorflow.org/api_docs/python/tf/keras/layers/Resizing
# - https://www.tensorflow.org/api_docs/python/tf/keras/layers/Rescaling
# - https://www.tensorflow.org/api_docs/python/tf/keras/layers/CenterCrop

# %%
# Couche de redimensionnement d'images
resizing_layer = tf.keras.layers.Resizing(
  img_height,
  img_width,
  interpolation='bilinear',
  crop_to_aspect_ratio=True
)

# %%
# Couche de normalisation d'images
rescaling_layer = tf.keras.layers.Rescaling(scale=1./255)

# %%
# Visualisation d'une image d'exemple
ex_img = X_train[7]
print(f"Shape de l'image : {ex_img.shape}")
# Out:
# Shape de l'image : (240, 320, 3)

# %%
# Redimensionnement de l'image
ex_img_resized = resizing_layer(ex_img)

# %%
# Mise à l'échelle de l'image (valeurs des pixels entre 0 et 1)
ex_img_resized_and_rescaled = rescaling_layer(ex_img_resized)

# %%
print(f"Shape de l'image redimensionnée et normalisée : {ex_img_resized_and_rescaled.shape}")
# Out:
# Shape de l'image redimensionnée et normalisée : (240, 320, 3)

# %%
# Verify that the pixels are in the [0, 1] range:
print("Valeurs minimum des pixels :", ex_img_resized_and_rescaled.numpy().min())
print("Valeurs maximum des pixels :", ex_img_resized_and_rescaled.numpy().max())
# Out:
# Valeurs minimum des pixels : 0.0
# Valeurs maximum des pixels : 0.9725491

# %% [markdown]
# ## Fonctions de callbacks pour l'entrainement
#
# **ReduceLROnPlateau** : Ce callback permet de réduire le taux d'apprentissage si une métrique surveillée (généralement la perte de validation) ne s'améliore pas pendant un certain nombre d'époques. Cela peut aider à empêcher le modèle de se sur-adapter (over-fit) aux données d'entraînement.
#
# **EarlyStopping** : Ce callback permet d'arrêter l'entraînement du modèle si une métrique surveillée ne s'améliore pas pendant un certain nombre d'époques. Cela peut aider à économiser du temps de calcul et à empêcher le modèle de se sur-adapter aux données d'entraînement.

# %%
# !pip install livelossplot --quiet

# %%
# Live training loss plot
# Log-loss (cost function) and accuracy
from livelossplot import PlotLossesKeras

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
rlrop = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3)
early = EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)

# %% [markdown]
# ## Architecture du modèle
#
# `functional API` de Keras permet de créer des modèles qui sont plus flexibles qu'avec `Sequential API`. `functional API` peut accepter des modèles non-linaires, avec des couches partagées, ou même avec des entrées et sorties multiples.
#
# L’idée principale est qu’un modèle d’apprentissage profond est généralement un `directed acyclic graph (DAG)` de couches. `functional API` est donc un moyen de créer des graphiques de couches.
#
# - https://keras.io/guides/functional_api/
# - https://keras.io/api/models/model/#model-class
# - https://keras.io/api/layers/core_layers/input/
# - https://stackoverflow.com/questions/44747343/keras-input-explanation-input-shape-units-batch-size-dim-etc
# - https://ressources.labomedia.org/keras_input_explanation

# %%
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.layers import Input, Lambda, Dense, Flatten

NBCLASSES = 2

def create_model():

  # Couche d'entrée des images
  # La couche Input converti les données d'entrée en Keras tensor.
  # L'argument 'shape' ne doit pas inclure la dimension du batch (le nombre d'images)
  # La valeur '[None, None]' permet de passer une taille d'images libre, elles seront redimensionnées par la couche suivante
  inputs = Input(shape=[None, None] + [img_channels])

  # Pré-traitement des images
  # Ajoute la couche de redimensionnement
  imgs_resized = resizing_layer(inputs)
  # Ajoute la couche de normalisation
  imgs_rescaled = rescaling_layer(imgs_resized)

  # Ajoute le modèle VGG16, pré-entrainé sur ImageNet
  # vgg = VGG16(input_shape=(img_height, img_width, img_depth), weights='imagenet', include_top=False)
  vgg = VGG16(
    include_top=False,
    weights="imagenet",
    input_tensor=imgs_rescaled, # Tenseur Keras facultatif (c'est-à-dire la sortie du layer.Input()) à utiliser comme entrée d'image pour le modèle.
    input_shape=(img_height, img_width, img_channels)
  )
  # Gèle des couches VGG avec les poids pré-entrainés
  for layer in vgg.layers:
      layer.trainable = False
  # Récupère la sortie de VGG
  vgg_out = vgg.output

  # Ajoute une couche Dense pour nos classes de sorties
  x = Flatten()(vgg_out)
  outputs = Dense(NBCLASSES, activation='softmax')(x)

  # Création du modèle
  model = Model(inputs=inputs, outputs=outputs, name="lr_vgg16_imagenet_model")
  model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=['accuracy'])
  model.summary()
  return model

lr_classifier = create_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "lr_vgg16_imagenet_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  resizing (Resizing)         (None, 240, 320, 3)       0
#
#  rescaling (Rescaling)       (None, 240, 320, 3)       0
#
#  block1_conv1 (Conv2D)       (None, 240, 320, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 240, 320, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 120, 160, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 120, 160, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 120, 160, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 60, 80, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 60, 80, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 60, 80, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 60, 80, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 30, 40, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 30, 40, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 30, 40, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 30, 40, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 20, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 20, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 20, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 20, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 10, 512)        0
#
#  flatten (Flatten)           (None, 35840)             0
#
#  dense (Dense)               (None, 2)                 71682
#
# =================================================================
# Total params: 14786370 (56.41 MB)
# Trainable params: 71682 (280.01 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# Affiche l'architecture du modèle avec les dimensions en entrée et sortie de chaque couche
tf.keras.utils.plot_model(lr_classifier, "lr_classifier_model_with_shape_info.png", show_shapes=True)

# %% [markdown]
# ## Entrainement du modèle

# %%
if TRAIN:
  lr_classifier_hist = lr_classifier.fit(
    X_train_aug,
    y_train_vect_aug,
    batch_size = 30,
    epochs = EPOCHS,
    validation_split=0.25,
    callbacks=[rlrop, early, PlotLossesKeras()]
  )

# %% [markdown]
# ## Sauvegarde du modèle
#
# - https://www.tensorflow.org/guide/keras/serialization_and_saving
# - https://www.tensorflow.org/guide/keras/serialization_and_saving#simple_exporting_with_export

# %%
lr_classifier_path = backup_folder + "lr_classifier.keras"

# %%
if TRAIN :
  lr_classifier.save(lr_classifier_path)

# %% [markdown]
# ## Sauvegarde du Label Encoder
#
# - https://www.digitalocean.com/community/tutorials/python-pickle-example

# %%
import pickle

lr_label_encoder_path = backup_folder + 'lr_label_encoder.pkl'

if TRAIN :
	# Open a file and use dump()
	# 'wb' = write binary
	with open(lr_label_encoder_path, 'wb') as file:
		# A new file will be created
		pickle.dump(label_enc_lr, file)
	# close the file
	file.close()

# %% [markdown]
# ## Chargé le classifier et label encoder

# %%
# Importer le modèle 'LR Classifier'
lr_classifier_loaded = tf.keras.models.load_model(lr_classifier_path)
lr_classifier.summary()
# Out:
# Model: "lr_vgg16_imagenet_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  resizing (Resizing)         (None, 240, 320, 3)       0
#
#  rescaling (Rescaling)       (None, 240, 320, 3)       0
#
#  block1_conv1 (Conv2D)       (None, 240, 320, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 240, 320, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 120, 160, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 120, 160, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 120, 160, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 60, 80, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 60, 80, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 60, 80, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 60, 80, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 30, 40, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 30, 40, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 30, 40, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 30, 40, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 20, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 20, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 20, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 20, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 10, 512)        0
#
#  flatten (Flatten)           (None, 35840)             0
#
#  dense (Dense)               (None, 2)                 71682
#
# =================================================================
# Total params: 14786370 (56.41 MB)
# Trainable params: 71682 (280.01 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# https://www.datacamp.com/tutorial/pickle-python-tutorial

# %%
# Importer le label encoder
# 'rb' = read binary
with open(lr_label_encoder_path, 'rb') as f:
  label_enc_lr_loaded = pickle.load(f) # deserialize using load()

label_enc_lr_loaded.classes_
# Out:
# array(['left', 'right'], dtype='<U5')

# %% [markdown]
# ## Prédictions avec les données de test (augmentées)

# %%
y_test_pred = [np.argmax(v) for v in lr_classifier_loaded.predict(X_test_aug)]  # Prédictions du modèle
# Out:
# 17/17 [==============================] - 25s 535ms/step

# %% [markdown]
# ## Affichage des performances

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, ConfusionMatrixDisplay

# Calcul de la matrice de confusion
conf_matrix = confusion_matrix(y_test_enc_aug, y_test_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=label_enc_lr.classes_)
disp.plot()
plt.show()

# %%
# Calcul des mesures de performance
accuracy = accuracy_score(y_test_enc_aug, y_test_pred)
precision = precision_score(y_test_enc_aug, y_test_pred,average='macro')
recall = recall_score(y_test_enc_aug, y_test_pred,average='macro')
f1 = f1_score(y_test_enc_aug, y_test_pred,average='macro')

print("Précision : {:.2f}".format(precision))
print("Rappel : {:.2f}".format(recall))
print("Score F1 : {:.2f}".format(f1))
print("Exactitude : {:.2f}".format(accuracy))
# Out:
# Précision : 0.99
# Rappel : 0.99
# Score F1 : 0.99
# Exactitude : 0.99

# %% [markdown]
# ## Inférence avec une image

# %%
test_image_path = '/content/MMU-Iris-Database-split/test/1/right/aevar3.bmp'

# %% [markdown]
# ### PIL

# %%
# PIL
test_img_pil = Image.open(test_image_path)
print(test_img_pil.format, test_img_pil.size, test_img_pil.mode)
# Out:
# BMP (320, 240) RGB

# %%
test_img_pil
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=320x240>

# %% [markdown]
# ### cv2

# %%
# cv2
test_img_cv2 = cv2.imread(test_image_path)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(test_img_cv2)
# Out:
# <PIL.Image.Image image mode=RGB size=320x240>

# %%
test_img_cv2.shape
# Out:
# (240, 320, 3)

# %%
def lr_inference(image_file):
  """
  Fonction qui réalise une prédiction à partir d'un fichier image (ndarray ou PIL Image).
  """
  # Ajout d'une dimension car le modèle accepte une liste d'images cad un objet à 4 dimensions.
  image_file_more_dims = np.expand_dims(image_file, axis=0)
  # Inférence
  pred = [np.argmax(v) for v in lr_classifier_loaded.predict(image_file_more_dims)][0]
  # Désencodage de l'index de classe en classe (string)
  pred_class_str = label_enc_lr.classes_[pred]
  # Retourne une string
  return pred_class_str

# %%
lr_inference(test_img_pil)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 'right'

# %%
lr_inference(test_img_cv2)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 'right'

# %% [markdown]
# ## Montrer les images mal classées

# %%
# Images mal classées
missed_imgs = X_test_aug[y_test_pred != y_test_enc_aug]
# Prédiction du classifieur
missed_pred = np.array(y_test_pred)[y_test_pred != y_test_enc_aug]
# Réalité terrain
missed_truth = y_test_enc_aug[y_test_pred != y_test_enc_aug]

# %%
# Prédiction du classifieur
label_enc_lr.classes_[missed_pred]
# Out:
# array(['right', 'left', 'left', 'left', 'left', 'left', 'left'],
#       dtype='<U5')

# %%
# Réalité terrain
label_enc_lr.classes_[missed_truth]
# Out:
# array(['left', 'right', 'right', 'right', 'right', 'right', 'right'],
#       dtype='<U5')

# %%
# Compte des images mal classées
missed_imgs_count = int(len(missed_imgs))
print(f"Il y a {imgs_missed_count} images où le classificateur se trompe.")
# Out:
# Il y a 7 images où le classificateur se trompe.

# %%
import math

# Montrer les images mal classées
cols = 4
rows = math.ceil(missed_imgs_count / cols)
plt.figure(figsize=(12, 8))
for i, img in enumerate(missed_imgs):
  plt.subplot(rows, cols, i + 1)
  plt.imshow(img.astype(np.uint8))
  plt.title(f'Augmented Image {i+1}')
plt.tight_layout()
plt.show()
